# %%
import register, imp
imp.reload(register)
import numpy as np
import matplotlib.pyplot as plt

ops = {
        'reg_file': 'H:/DATA/TX18_2018_06_14_1_plane7.bin',
        'Lx':488,
        'Ly':454,
        'diameter':10,
        'tau':  1., # this is the only parameter used for deconvolution per se        
        'fs': 10.,  # sampling rate        
        'baseline': 'maximin', # baselining mode
        'win_baseline': 60., # window for maximin
        'sig_baseline': 10., # smoothing constant for gaussian filter 
        'prctile_baseline': 8.,# smoothing constant for gaussian filter        
        'neucoeff': .7,  # neuropil coefficient 
        'neumax': 1.,  # maximum neuropil coefficient (not implemented)
        'niterneu': 5, # number of iterations when the neuropil coefficient is estimated (not implemented)
        'maxregshift': 0.,
        'subpixel' : 10,
        'batch_size': 400, 
        'num_workers': 0, # 0 to select automatically, -1 to disable parallelism, N to enforce value
      }

Ly = ops['Ly']
Lx = ops['Lx']
nbatch = ops['batch_size']

# %%
reg_file = open(ops['reg_file'], 'rb+')
nbytesread = 2 * Ly * Lx 
buff = reg_file.read(nbytesread)
data = np.frombuffer(buff, dtype=np.int16, offset=0)
data = np.reshape(data, ( Ly, Lx)).astype('float32')

refImg = data.astype('float32')
reg_file.close()

# %%
import time


tstart = time.time()

nbytesread = 2 * Ly * Lx * nbatch

reg_file = open(ops['reg_file'], 'rb+')
#reg_file = open('H:/DATA/test.bin', 'rb+')

ibatch = 0
for i in range(0,10):
    buff = reg_file.read(nbytesread)

    data = np.frombuffer(buff, dtype=np.int16, offset=0)
    if data.size==0:
        break
        
    ibatch += 1
    print(ibatch)
    
    data = np.reshape(data, (-1, Ly, Lx)).astype('float32')
    
    dwrite, ymax, xmax = register.phasecorr(data, refImg, ops)

    dwrite = dwrite.astype('int16')
    reg_file.seek(-nbytesread,1)
    reg_file.write(dwrite);

reg_file.close()

tend = time.time()

print(tend-tstart)
# Out:
# 1
# 4.198771238327026

# %%
a = np.array([])
print a.size # 0

# %%
data.shape
# Out:
# (400, 454, 488)

# %%
reg_file2 = open('H:/DATA/test.bin', 'wb')

dwrite = data.astype('int16')

reg_file2.write(dwrite);

reg_file2.close()

# %%
reg_file2 = open('H:/DATA/test.bin', 'rb')

nbytesread = 2 * Ly * Lx * nbatch
buff = reg_file2.read(nbytesread)
data = np.frombuffer(buff, dtype=np.int16, offset=0)
data = np.reshape(data, (-1, Ly, Lx)).astype('float32')

# %%
plt.figure(figsize=(14,12))
plt.imshow(X[220,:,:])
plt.show()

# %%
mov = np.zeros((ops['navg_frames_svd'], ops['Ly'], ops['Lx']), np.float32)

Ly = ops['Ly']
Lx = ops['Lx']
ny = ops['ny']
nx = ops['nx']

nimgbatch = int(nimgbatch)
block_size = ny*nx*nimgbatch*2
ix = 0
with open(ops['reg_file'], 'rb') as reg_file:
    buff = reg_file.read(block_size)
    while buff != '':
        ## FIX LAST FRAME ISSUE !!!
        buff = reg_file.read(block_size)
        data = np.frombuffer(buff, dtype=np.int16, offset=0)
        nimgd = int(np.floor(data.size / (ny*nx)))
        data = np.reshape(data.astype(np.float32), (ny,nx,nimgd), order='F')
        data = np.transpose(data, (2,0,1))
        # subtract mean of batch
        data = data - data.mean(axis=0)
        # bin data
        if nimgd < nimgbatch:
            nmax = int(np.floor(nimgd / nt0) * nt0)
            data = data[:nmax,:,:]
        dbin = np.reshape(data, (nt0,-1,ny,nx))
        dbin = np.squeeze(dbin.mean(axis=0))
        print(dbin.shape)
        inds = ix + np.arange(0,dbin.shape[0])
        # crop into valid area
        mov[inds,:,:] = dbin[:, ops['yrange'][0]:ops['yrange'][-1]+1, ops['xrange'][0]:ops['xrange'][-1]+1]
        ix += dbin.shape[0]

mov = np.reshape(mov, (mov.shape[0],Ly*Lx))
